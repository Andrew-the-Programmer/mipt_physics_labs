# %%
import numpy as np
from matplotlib import pyplot as plt
from scipy import optimize
# Out:
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
def lin(x, k, b):
    return k * x + b

# %%
P = np.array([1.0, 1.1, 1.1, 1.2, 1.4, 1.6, 1.7, 1.9, 2.0, 2.2, 2.4, 2.5, 2.7, 2.8, 3.0, 3.1, 3.2, 3.4, 3.5,
              3.7, 3.8, 4.0, 4.1, 4.3, 4.4, 4.5, 4.7, 4.8, 5.0, 5.1, 5.2, 5.4])
#P = np.log(P1 - 0.9)
dt = 2
t = np.arange(0, len(P) *2, 2)
coef, err = optimize.curve_fit(lin, t, P)
x = np.arange(min(t), max(t)+0.02, 0.01)
y = lin(x, coef[0], coef[1])

plt.plot(t, P, 'o')
plt.plot(x, y)
plt.xlabel('t, сек')
plt.ylabel('P, 10^-4 торр')
coef
# Out:
# array([0.07309384, 0.88409091])

# %%
P = np.array([5.7, 4.7, 3.3, 2.4, 1.9, 1.6, 1.5, 1.3, 1.3, 1.2, 1.2, 1.1, 1.1, 1.1])
P = np.log(P - 0.9)
dt = 2
t = np.arange(0, len(P) *2, 2)
coef, err = optimize.curve_fit(lin, t, P)
x = np.arange(min(t), max(t)+0.02, 0.01)
y = lin(x, coef[0], coef[1])

plt.plot(t, P, 'o')
plt.plot(x, y)
plt.xlabel('t, сек')
plt.ylabel('ln(P-P0)')
coef
# Out:
# array([-0.12685487,  1.23827111])

# %%
P = np.array([1.2, 1.3, 1.5, 1.6, 1.8, 1.9, 2.1, 2.3, 2.4, 2.6, 2.7, 2.9, 3.0, 3.2, 3.3, 3.5, 3.7, 3.8])
#P = np.log(P1 - 0.9)
dt = 2
t = np.arange(0, len(P) *2, 2)
coef, err = optimize.curve_fit(lin, t, P)
x = np.arange(min(t), max(t)+0.02, 0.01)
y = lin(x, coef[0], coef[1])

plt.plot(t, P, 'o')
plt.plot(x, y)
plt.xlabel('t, сек')
plt.ylabel('P, 10^-4 торр')
coef
# Out:
# array([0.07770898, 1.16783626])

# %%
P = np.array([5.8, 5.3, 4.6, 3.9, 3.3, 2.8, 2.5, 2.2, 2.0, 1.8, 1.7, 1.6, 1.5, 1.4, 1.4, 1.3, 1.3, 1.2, 1.2, 1.2])
P = np.log(P - 0.9)
dt = 1
t = np.arange(0, len(P) *dt, dt)
coef, err = optimize.curve_fit(lin, t, P)
x = np.arange(min(t), max(t)+0.02, 0.01)
y = lin(x, coef[0], coef[1])

plt.plot(t, P, 'o')
plt.plot(x, y)
plt.xlabel('t, сек')
plt.ylabel('ln(P-P0)')
coef
# Out:
# array([-0.15624827,  1.47415789])

# %%
#251
P = (np.array([205.4, 205, 204.2, 202.4, 
               201.4, 199.8, 199, 197.4]) * 0.2 * 9.80665 - 1000 * 9.8 * 0.021) * 1.1 / 1000 / 4
T = np.arange(25, 61, 5)
coef, err = optimize.curve_fit(lin, T, P)
x = np.arange(min(T), max(T)+0.02, 0.01)
y1 = lin(x, coef[0], coef[1])
plt.plot(T, P, 'o')
plt.plot(x, y1)
plt.xlabel(r'T, $^o C$')
plt.ylabel(r'$\sigma$, Н/м')
coef
# Out:
# array([-0.00012868,  0.05773128])

# %%
def lin2(k, x):
    return k * x

x = np.arange(min(T), max(T)+0.02, 0.01)
y = lin(x + 273, -coef[0], 0)
plt.plot(x, y+y1)
plt.xlabel(r'T, $^o C$')
#plt.ylim(0, 0.02)
plt.ylabel(r'$\dfrac{U}{F}$ Дж/м^2')
# Out:
# Text(0, 0.5, '$\\dfrac{U}{F}$ Дж/м^2')
